# %% [markdown]
# <a href="https://colab.research.google.com/github/psykeefuego/DS---ML/blob/main/Week8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 30/05/24
#
# # Artificial Neural Network

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
from sklearn.datasets import load_iris

import keras
import tensorflow as tf

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
from keras.utils import to_categorical

# %%
# Load the iris dataset
iris = load_iris()
data = pd.DataFrame(iris.data, columns=iris.feature_names)
data['target'] = iris.target.reshape(-1, 1)

# %%
# Prepare the data
X = data.drop('target', axis=1)
y = data['target']
y_one_hot = to_categorical(y)  # Convert to one-hot encoded vectors

# %%
# Split the data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot, test_size=0.2)

# %%
# Deep feed forward network i.e. the layers are constructed sequentially
model = Sequential()

# %%
# 3 layered neural network
model.add(Dense(10, input_shape=(4,), activation='relu', name='ly1'))  # input layer with 10 neurons
model.add(Dense(10, activation='relu', name='ly2'))  # middle layer with 10 neurons
model.add(Dense(3, activation='softmax', name='ly3'))  # output layer

# layer 1 : 10 neurons x 4 inputs + 10 bias = 50 params
# layer 2 : 10 neurons x

# %%
# Adam optimizer with a learning rate of 0.001
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer, loss='categorical_crossentropy', metrics=['accuracy', 'AUC'])

# %%
print('Neural Network Model Summary:')
print(model.summary())
# Out:
# Neural Network Model Summary:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ly1 (Dense)                 (None, 10)                50
#
#  ly2 (Dense)                 (None, 10)                110
#
#  ly3 (Dense)                 (None, 3)                 33
#
# =================================================================
# Total params: 193 (772.00 Byte)
# Trainable params: 193 (772.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
# Training the model
model.fit(X_train, y_train, verbose=2, batch_size=10, epochs=200)
# Out:
# Epoch 1/200
# 12/12 - 1s - loss: 1.2868 - accuracy: 0.3583 - auc: 0.5343 - 863ms/epoch - 72ms/step
# Epoch 2/200
# 12/12 - 0s - loss: 1.1416 - accuracy: 0.3417 - auc: 0.5405 - 25ms/epoch - 2ms/step
# Epoch 3/200
# 12/12 - 0s - loss: 1.0434 - accuracy: 0.2250 - auc: 0.5852 - 36ms/epoch - 3ms/step
# Epoch 4/200
# 12/12 - 0s - loss: 0.9635 - accuracy: 0.2250 - auc: 0.6107 - 29ms/epoch - 2ms/step
# Epoch 5/200
# 12/12 - 0s - loss: 0.9086 - accuracy: 0.4000 - auc: 0.7048 - 27ms/epoch - 2ms/step
# Epoch 6/200
# 12/12 - 0s - loss: 0.8497 - accuracy: 0.6250 - auc: 0.7886 - 27ms/epoch - 2ms/step
# Epoch 7/200
# 12/12 - 0s - loss: 0.8059 - accuracy: 0.6417 - auc: 0.8420 - 28ms/epoch - 2ms/step
# Epoch 8/200
# 12/12 - 0s - loss: 0.7741 - accuracy: 0.6417 - auc: 0.8804 - 26ms/epoch - 2ms/step
# Epoch 9/200
# 12/12 - 0s - loss: 0.7494 - accuracy: 0.6500 - auc: 0.8915 - 28ms/epoch - 2ms/step
# Epoch 10/200
# 12/12 - 0s - loss: 0.7275 - accuracy: 0.7333 - auc: 0.9070 - 26ms/epoch - 2ms/step
# Epoch 11/200
# 12/12 - 0s - loss: 0.6969 - accuracy: 0.6833 - auc: 0.9082 - 27ms/epoch - 2ms/step
# Epoch 12/200
# 12/12 - 0s - loss: 0.6668 - accuracy: 0.6417 - auc: 0.9167 - 28ms/epoch - 2ms/step
# Epoch 13/200
# 12/12 - 0s - loss: 0.6421 - accuracy: 0.6417 - auc: 0.9218 - 29ms/epoch - 2ms/step
# Epoch 14/200
# 12/12 - 0s - loss: 0.6179 - accuracy: 0.6417 - auc: 0.9231 - 26ms/epoch - 2ms/step
# Epoch 15/200
# 12/12 - 0s - loss: 0.5991 - accuracy: 0.6417 - auc: 0.9241 - 26ms/epoch - 2ms/step
# Epoch 16/200
# 12/12 - 0s - loss: 0.5783 - accuracy: 0.6417 - auc: 0.9274 - 25ms/epoch - 2ms/step
# Epoch 17/200
# 12/12 - 0s - loss: 0.5600 - accuracy: 0.6583 - auc: 0.9318 - 25ms/epoch - 2ms/step
# Epoch 18/200
# 12/12 - 0s - loss: 0.5460 - accuracy: 0.7083 - auc: 0.9377 - 25ms/epoch - 2ms/step
# Epoch 19/200
# 12/12 - 0s - loss: 0.5304 - accuracy: 0.7333 - auc: 0.9438 - 29ms/epoch - 2ms/step
# Epoch 20/200
# 12/12 - 0s - loss: 0.5178 - accuracy: 0.7083 - auc: 0.9396 - 26ms/epoch - 2ms/step
# Epoch 21/200
# 12/12 - 0s - loss: 0.5048 - accuracy: 0.8083 - auc: 0.9547 - 29ms/epoch - 2ms/step
# Epoch 22/200
# 12/12 - 0s - loss: 0.4951 - accuracy: 0.8917 - auc: 0.9699 - 25ms/epoch - 2ms/step
# Epoch 23/200
# 12/12 - 0s - loss: 0.4845 - accuracy: 0.9083 - auc: 0.9784 - 25ms/epoch - 2ms/step
# Epoch 24/200
# 12/12 - 0s - loss: 0.4764 - accuracy: 0.8750 - auc: 0.9688 - 26ms/epoch - 2ms/step
# Epoch 25/200
# 12/12 - 0s - loss: 0.4662 - accuracy: 0.9250 - auc: 0.9836 - 28ms/epoch - 2ms/step
# Epoch 26/200
# 12/12 - 0s - loss: 0.4580 - accuracy: 0.9417 - auc: 0.9881 - 32ms/epoch - 3ms/step
# Epoch 27/200
# 12/12 - 0s - loss: 0.4486 - accuracy: 0.9250 - auc: 0.9866 - 34ms/epoch - 3ms/step
# Epoch 28/200
# 12/12 - 0s - loss: 0.4408 - accuracy: 0.9250 - auc: 0.9857 - 27ms/epoch - 2ms/step
# Epoch 29/200
# 12/12 - 0s - loss: 0.4343 - accuracy: 0.9333 - auc: 0.9866 - 30ms/epoch - 2ms/step
# Epoch 30/200
# 12/12 - 0s - loss: 0.4288 - accuracy: 0.9500 - auc: 0.9913 - 26ms/epoch - 2ms/step
# Epoch 31/200
# 12/12 - 0s - loss: 0.4185 - accuracy: 0.9500 - auc: 0.9941 - 33ms/epoch - 3ms/step
# Epoch 32/200
# 12/12 - 0s - loss: 0.4127 - accuracy: 0.9333 - auc: 0.9874 - 26ms/epoch - 2ms/step
# Epoch 33/200
# 12/12 - 0s - loss: 0.4039 - accuracy: 0.9333 - auc: 0.9898 - 27ms/epoch - 2ms/step
# Epoch 34/200
# 12/12 - 0s - loss: 0.4004 - accuracy: 0.9417 - auc: 0.9935 - 31ms/epoch - 3ms/step
# Epoch 35/200
# 12/12 - 0s - loss: 0.3922 - accuracy: 0.9583 - auc: 0.9937 - 30ms/epoch - 2ms/step
# Epoch 36/200
# 12/12 - 0s - loss: 0.3845 - accuracy: 0.9333 - auc: 0.9954 - 26ms/epoch - 2ms/step
# Epoch 37/200
# 12/12 - 0s - loss: 0.3771 - accuracy: 0.9583 - auc: 0.9961 - 28ms/epoch - 2ms/step
# Epoch 38/200
# 12/12 - 0s - loss: 0.3751 - accuracy: 0.9333 - auc: 0.9917 - 29ms/epoch - 2ms/step
# Epoch 39/200
# 12/12 - 0s - loss: 0.3634 - accuracy: 0.9583 - auc: 0.9963 - 29ms/epoch - 2ms/step
# Epoch 40/200
# 12/12 - 0s - loss: 0.3609 - accuracy: 0.9583 - auc: 0.9967 - 28ms/epoch - 2ms/step
# Epoch 41/200
# 12/12 - 0s - loss: 0.3506 - accuracy: 0.9583 - auc: 0.9969 - 26ms/epoch - 2ms/step
# Epoch 42/200
# 12/12 - 0s - loss: 0.3441 - accuracy: 0.9583 - auc: 0.9965 - 26ms/epoch - 2ms/step
# Epoch 43/200
# 12/12 - 0s - loss: 0.3402 - accuracy: 0.9417 - auc: 0.9949 - 29ms/epoch - 2ms/step
# Epoch 44/200
# 12/12 - 0s - loss: 0.3305 - accuracy: 0.9583 - auc: 0.9968 - 31ms/epoch - 3ms/step
# Epoch 45/200
# 12/12 - 0s - loss: 0.3262 - accuracy: 0.9417 - auc: 0.9971 - 25ms/epoch - 2ms/step
# Epoch 46/200
# 12/12 - 0s - loss: 0.3189 - accuracy: 0.9667 - auc: 0.9978 - 26ms/epoch - 2ms/step
# Epoch 47/200
# 12/12 - 0s - loss: 0.3131 - accuracy: 0.9583 - auc: 0.9970 - 27ms/epoch - 2ms/step
# Epoch 48/200
# 12/12 - 0s - loss: 0.3061 - accuracy: 0.9500 - auc: 0.9970 - 27ms/epoch - 2ms/step
# Epoch 49/200
# 12/12 - 0s - loss: 0.3000 - accuracy: 0.9667 - auc: 0.9974 - 111ms/epoch - 9ms/step
# Epoch 50/200
# 12/12 - 0s - loss: 0.2950 - accuracy: 0.9667 - auc: 0.9980 - 122ms/epoch - 10ms/step
# Epoch 51/200
# 12/12 - 0s - loss: 0.2883 - accuracy: 0.9667 - auc: 0.9982 - 119ms/epoch - 10ms/step
# Epoch 52/200
# 12/12 - 0s - loss: 0.2829 - accuracy: 0.9667 - auc: 0.9980 - 66ms/epoch - 5ms/step
# Epoch 53/200
# 12/12 - 0s - loss: 0.2775 - accuracy: 0.9583 - auc: 0.9978 - 47ms/epoch - 4ms/step
# Epoch 54/200
# 12/12 - 0s - loss: 0.2712 - accuracy: 0.9667 - auc: 0.9973 - 29ms/epoch - 2ms/step
# Epoch 55/200
# 12/12 - 0s - loss: 0.2688 - accuracy: 0.9583 - auc: 0.9976 - 27ms/epoch - 2ms/step
# Epoch 56/200
# 12/12 - 0s - loss: 0.2603 - accuracy: 0.9750 - auc: 0.9982 - 26ms/epoch - 2ms/step
# Epoch 57/200
# 12/12 - 0s - loss: 0.2576 - accuracy: 0.9583 - auc: 0.9975 - 25ms/epoch - 2ms/step
# Epoch 58/200
# 12/12 - 0s - loss: 0.2501 - accuracy: 0.9583 - auc: 0.9981 - 28ms/epoch - 2ms/step
# Epoch 59/200
# 12/12 - 0s - loss: 0.2440 - accuracy: 0.9667 - auc: 0.9983 - 29ms/epoch - 2ms/step
# Epoch 60/200
# 12/12 - 0s - loss: 0.2401 - accuracy: 0.9667 - auc: 0.9981 - 26ms/epoch - 2ms/step
# Epoch 61/200
# 12/12 - 0s - loss: 0.2352 - accuracy: 0.9667 - auc: 0.9981 - 27ms/epoch - 2ms/step
# Epoch 62/200
# 12/12 - 0s - loss: 0.2289 - accuracy: 0.9667 - auc: 0.9985 - 29ms/epoch - 2ms/step
# Epoch 63/200
# 12/12 - 0s - loss: 0.2275 - accuracy: 0.9583 - auc: 0.9981 - 28ms/epoch - 2ms/step
# Epoch 64/200
# 12/12 - 0s - loss: 0.2209 - accuracy: 0.9667 - auc: 0.9982 - 26ms/epoch - 2ms/step
# Epoch 65/200
# 12/12 - 0s - loss: 0.2167 - accuracy: 0.9667 - auc: 0.9986 - 25ms/epoch - 2ms/step
# Epoch 66/200
# 12/12 - 0s - loss: 0.2124 - accuracy: 0.9667 - auc: 0.9983 - 25ms/epoch - 2ms/step
# Epoch 67/200
# 12/12 - 0s - loss: 0.2080 - accuracy: 0.9667 - auc: 0.9983 - 26ms/epoch - 2ms/step
# Epoch 68/200
# 12/12 - 0s - loss: 0.2040 - accuracy: 0.9667 - auc: 0.9983 - 27ms/epoch - 2ms/step
# Epoch 69/200
# 12/12 - 0s - loss: 0.2016 - accuracy: 0.9583 - auc: 0.9984 - 29ms/epoch - 2ms/step
# Epoch 70/200
# 12/12 - 0s - loss: 0.1975 - accuracy: 0.9750 - auc: 0.9984 - 28ms/epoch - 2ms/step
# Epoch 71/200
# 12/12 - 0s - loss: 0.1982 - accuracy: 0.9583 - auc: 0.9977 - 26ms/epoch - 2ms/step
# Epoch 72/200
# 12/12 - 0s - loss: 0.1916 - accuracy: 0.9667 - auc: 0.9982 - 25ms/epoch - 2ms/step
# Epoch 73/200
# 12/12 - 0s - loss: 0.1918 - accuracy: 0.9583 - auc: 0.9977 - 28ms/epoch - 2ms/step
# Epoch 74/200
# 12/12 - 0s - loss: 0.1817 - accuracy: 0.9750 - auc: 0.9990 - 26ms/epoch - 2ms/step
# Epoch 75/200
# 12/12 - 0s - loss: 0.1818 - accuracy: 0.9667 - auc: 0.9982 - 27ms/epoch - 2ms/step
# Epoch 76/200
# 12/12 - 0s - loss: 0.1776 - accuracy: 0.9583 - auc: 0.9984 - 26ms/epoch - 2ms/step
# Epoch 77/200
# 12/12 - 0s - loss: 0.1746 - accuracy: 0.9583 - auc: 0.9984 - 25ms/epoch - 2ms/step
# Epoch 78/200
# Epoch 122/200
# 12/12 - 0s - loss: 0.1059 - accuracy: 0.9583 - auc: 0.9987 - 28ms/epoch - 2ms/step
# Epoch 123/200
# 12/12 - 0s - loss: 0.1076 - accuracy: 0.9833 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 124/200
# 12/12 - 0s - loss: 0.1051 - accuracy: 0.9667 - auc: 0.9985 - 28ms/epoch - 2ms/step
# Epoch 125/200
# 12/12 - 0s - loss: 0.1053 - accuracy: 0.9667 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 126/200
# 12/12 - 0s - loss: 0.1032 - accuracy: 0.9583 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 127/200
# 12/12 - 0s - loss: 0.1034 - accuracy: 0.9833 - auc: 0.9987 - 25ms/epoch - 2ms/step
# Epoch 128/200
# 12/12 - 0s - loss: 0.1024 - accuracy: 0.9833 - auc: 0.9988 - 28ms/epoch - 2ms/step
# Epoch 129/200
# 12/12 - 0s - loss: 0.1038 - accuracy: 0.9583 - auc: 0.9986 - 26ms/epoch - 2ms/step
# Epoch 130/200
# 12/12 - 0s - loss: 0.1037 - accuracy: 0.9750 - auc: 0.9986 - 25ms/epoch - 2ms/step
# Epoch 131/200
# 12/12 - 0s - loss: 0.1002 - accuracy: 0.9750 - auc: 0.9986 - 26ms/epoch - 2ms/step
# Epoch 132/200
# 12/12 - 0s - loss: 0.0988 - accuracy: 0.9667 - auc: 0.9988 - 26ms/epoch - 2ms/step
# Epoch 133/200
# 12/12 - 0s - loss: 0.1035 - accuracy: 0.9667 - auc: 0.9986 - 25ms/epoch - 2ms/step
# Epoch 134/200
# 12/12 - 0s - loss: 0.1016 - accuracy: 0.9667 - auc: 0.9985 - 25ms/epoch - 2ms/step
# Epoch 135/200
# 12/12 - 0s - loss: 0.1001 - accuracy: 0.9667 - auc: 0.9984 - 34ms/epoch - 3ms/step
# Epoch 136/200
# 12/12 - 0s - loss: 0.0972 - accuracy: 0.9750 - auc: 0.9987 - 31ms/epoch - 3ms/step
# Epoch 137/200
# 12/12 - 0s - loss: 0.0968 - accuracy: 0.9667 - auc: 0.9987 - 25ms/epoch - 2ms/step
# Epoch 138/200
# 12/12 - 0s - loss: 0.0979 - accuracy: 0.9667 - auc: 0.9985 - 30ms/epoch - 2ms/step
# Epoch 139/200
# 12/12 - 0s - loss: 0.0966 - accuracy: 0.9750 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 140/200
# 12/12 - 0s - loss: 0.0974 - accuracy: 0.9583 - auc: 0.9989 - 33ms/epoch - 3ms/step
# Epoch 141/200
# 12/12 - 0s - loss: 0.0978 - accuracy: 0.9750 - auc: 0.9985 - 35ms/epoch - 3ms/step
# Epoch 142/200
# 12/12 - 0s - loss: 0.0949 - accuracy: 0.9750 - auc: 0.9986 - 26ms/epoch - 2ms/step
# Epoch 143/200
# 12/12 - 0s - loss: 0.0946 - accuracy: 0.9667 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 144/200
# 12/12 - 0s - loss: 0.0935 - accuracy: 0.9667 - auc: 0.9987 - 26ms/epoch - 2ms/step
# Epoch 145/200
# 12/12 - 0s - loss: 0.0943 - accuracy: 0.9583 - auc: 0.9988 - 33ms/epoch - 3ms/step
# Epoch 146/200
# 12/12 - 0s - loss: 0.0936 - accuracy: 0.9750 - auc: 0.9986 - 28ms/epoch - 2ms/step
# Epoch 147/200
# 12/12 - 0s - loss: 0.0942 - accuracy: 0.9667 - auc: 0.9985 - 29ms/epoch - 2ms/step
# Epoch 148/200
# 12/12 - 0s - loss: 0.0916 - accuracy: 0.9667 - auc: 0.9986 - 26ms/epoch - 2ms/step
# Epoch 149/200
# 12/12 - 0s - loss: 0.0916 - accuracy: 0.9667 - auc: 0.9986 - 26ms/epoch - 2ms/step
# Epoch 150/200
# 12/12 - 0s - loss: 0.0903 - accuracy: 0.9667 - auc: 0.9988 - 26ms/epoch - 2ms/step
# Epoch 151/200
# 12/12 - 0s - loss: 0.0907 - accuracy: 0.9750 - auc: 0.9987 - 26ms/epoch - 2ms/step
# Epoch 152/200
# 12/12 - 0s - loss: 0.0899 - accuracy: 0.9750 - auc: 0.9987 - 32ms/epoch - 3ms/step
# Epoch 153/200
# 12/12 - 0s - loss: 0.0900 - accuracy: 0.9667 - auc: 0.9986 - 27ms/epoch - 2ms/step
# Epoch 154/200
# 12/12 - 0s - loss: 0.0898 - accuracy: 0.9667 - auc: 0.9986 - 31ms/epoch - 3ms/step
# Epoch 155/200
# 12/12 - 0s - loss: 0.0920 - accuracy: 0.9583 - auc: 0.9986 - 29ms/epoch - 2ms/step
# Epoch 156/200
# 12/12 - 0s - loss: 0.0866 - accuracy: 0.9667 - auc: 0.9990 - 24ms/epoch - 2ms/step
# Epoch 157/200
# 12/12 - 0s - loss: 0.0873 - accuracy: 0.9750 - auc: 0.9988 - 25ms/epoch - 2ms/step
# Epoch 158/200
# 12/12 - 0s - loss: 0.0881 - accuracy: 0.9750 - auc: 0.9987 - 28ms/epoch - 2ms/step
# Epoch 159/200
# 12/12 - 0s - loss: 0.0907 - accuracy: 0.9583 - auc: 0.9986 - 29ms/epoch - 2ms/step
# Epoch 160/200
# 12/12 - 0s - loss: 0.0876 - accuracy: 0.9750 - auc: 0.9987 - 27ms/epoch - 2ms/step
# Epoch 161/200
# 12/12 - 0s - loss: 0.0860 - accuracy: 0.9750 - auc: 0.9989 - 25ms/epoch - 2ms/step
# Epoch 162/200
# 12/12 - 0s - loss: 0.0868 - accuracy: 0.9750 - auc: 0.9986 - 25ms/epoch - 2ms/step
# Epoch 163/200
# 12/12 - 0s - loss: 0.0876 - accuracy: 0.9750 - auc: 0.9985 - 45ms/epoch - 4ms/step
# Epoch 164/200
# 12/12 - 0s - loss: 0.0888 - accuracy: 0.9750 - auc: 0.9987 - 39ms/epoch - 3ms/step
# Epoch 165/200
# 12/12 - 0s - loss: 0.0931 - accuracy: 0.9583 - auc: 0.9984 - 38ms/epoch - 3ms/step
# Epoch 166/200
# 12/12 - 0s - loss: 0.0839 - accuracy: 0.9750 - auc: 0.9989 - 40ms/epoch - 3ms/step
# Epoch 167/200
# 12/12 - 0s - loss: 0.0891 - accuracy: 0.9667 - auc: 0.9986 - 40ms/epoch - 3ms/step
# Epoch 168/200
# 12/12 - 0s - loss: 0.0882 - accuracy: 0.9750 - auc: 0.9987 - 48ms/epoch - 4ms/step
# Epoch 169/200
# 12/12 - 0s - loss: 0.0828 - accuracy: 0.9750 - auc: 0.9990 - 54ms/epoch - 5ms/step
# Epoch 170/200
# 12/12 - 0s - loss: 0.0841 - accuracy: 0.9667 - auc: 0.9988 - 46ms/epoch - 4ms/step
# Epoch 171/200
# 12/12 - 0s - loss: 0.0835 - accuracy: 0.9667 - auc: 0.9987 - 43ms/epoch - 4ms/step
# Epoch 172/200
# 12/12 - 0s - loss: 0.0834 - accuracy: 0.9750 - auc: 0.9987 - 37ms/epoch - 3ms/step
# Epoch 173/200
# 12/12 - 0s - loss: 0.0828 - accuracy: 0.9667 - auc: 0.9986 - 39ms/epoch - 3ms/step
# Epoch 174/200
# 12/12 - 0s - loss: 0.0840 - accuracy: 0.9667 - auc: 0.9988 - 44ms/epoch - 4ms/step
# Epoch 175/200
# 12/12 - 0s - loss: 0.0886 - accuracy: 0.9750 - auc: 0.9985 - 36ms/epoch - 3ms/step
# Epoch 176/200
# 12/12 - 0s - loss: 0.0810 - accuracy: 0.9750 - auc: 0.9989 - 37ms/epoch - 3ms/step
# Epoch 177/200
# 12/12 - 0s - loss: 0.0845 - accuracy: 0.9583 - auc: 0.9986 - 37ms/epoch - 3ms/step
# Epoch 178/200
# 12/12 - 0s - loss: 0.0859 - accuracy: 0.9750 - auc: 0.9986 - 36ms/epoch - 3ms/step
# Epoch 179/200
# 12/12 - 0s - loss: 0.0811 - accuracy: 0.9833 - auc: 0.9987 - 35ms/epoch - 3ms/step
# Epoch 180/200
# 12/12 - 0s - loss: 0.0822 - accuracy: 0.9583 - auc: 0.9989 - 37ms/epoch - 3ms/step
# Epoch 181/200
# 12/12 - 0s - loss: 0.0815 - accuracy: 0.9750 - auc: 0.9989 - 42ms/epoch - 4ms/step
# Epoch 182/200
# 12/12 - 0s - loss: 0.0815 - accuracy: 0.9750 - auc: 0.9988 - 43ms/epoch - 4ms/step
# Epoch 183/200
# 12/12 - 0s - loss: 0.0800 - accuracy: 0.9750 - auc: 0.9986 - 37ms/epoch - 3ms/step
# Epoch 184/200
# 12/12 - 0s - loss: 0.0801 - accuracy: 0.9667 - auc: 0.9989 - 38ms/epoch - 3ms/step
# Epoch 185/200
# 12/12 - 0s - loss: 0.0820 - accuracy: 0.9750 - auc: 0.9986 - 41ms/epoch - 3ms/step
# Epoch 186/200
# 12/12 - 0s - loss: 0.0819 - accuracy: 0.9833 - auc: 0.9986 - 39ms/epoch - 3ms/step
# Epoch 187/200
# 12/12 - 0s - loss: 0.0791 - accuracy: 0.9667 - auc: 0.9988 - 38ms/epoch - 3ms/step
# Epoch 188/200
# 12/12 - 0s - loss: 0.0789 - accuracy: 0.9667 - auc: 0.9988 - 38ms/epoch - 3ms/step
# Epoch 189/200
# 12/12 - 0s - loss: 0.0833 - accuracy: 0.9750 - auc: 0.9984 - 35ms/epoch - 3ms/step
# Epoch 190/200
# 12/12 - 0s - loss: 0.0816 - accuracy: 0.9750 - auc: 0.9987 - 38ms/epoch - 3ms/step
# Epoch 191/200
# 12/12 - 0s - loss: 0.0803 - accuracy: 0.9750 - auc: 0.9986 - 41ms/epoch - 3ms/step
# Epoch 192/200
# 12/12 - 0s - loss: 0.0779 - accuracy: 0.9750 - auc: 0.9989 - 41ms/epoch - 3ms/step
# Epoch 193/200
# 12/12 - 0s - loss: 0.0838 - accuracy: 0.9667 - auc: 0.9985 - 45ms/epoch - 4ms/step
# Epoch 194/200
# 12/12 - 0s - loss: 0.0782 - accuracy: 0.9750 - auc: 0.9987 - 45ms/epoch - 4ms/step
# Epoch 195/200
# 12/12 - 0s - loss: 0.0804 - accuracy: 0.9750 - auc: 0.9987 - 38ms/epoch - 3ms/step
# Epoch 196/200
# 12/12 - 0s - loss: 0.0795 - accuracy: 0.9750 - auc: 0.9986 - 44ms/epoch - 4ms/step
# Epoch 197/200
# 12/12 - 0s - loss: 0.0784 - accuracy: 0.9750 - auc: 0.9988 - 40ms/epoch - 3ms/step
# Epoch 198/200
# 12/12 - 0s - loss: 0.0774 - accuracy: 0.9750 - auc: 0.9987 - 39ms/epoch - 3ms/step
# Epoch 199/200
# 12/12 - 0s - loss: 0.0795 - accuracy: 0.9667 - auc: 0.9987 - 42ms/epoch - 3ms/step
# Epoch 200/200
# 12/12 - 0s - loss: 0.0773 - accuracy: 0.9750 - auc: 0.9987 - 45ms/epoch - 4ms/step

# %%
# Evaluate the model
loss, accuracy, auc = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.4f}')
print(f'Test accuracy: {accuracy:.4f}')
print(f'Test AUC: {auc: .4f}')
# Out:
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0775 - accuracy: 0.9667 - auc: 0.9983
# Test loss: 0.0775
# Test accuracy: 0.9667
# Test AUC:  0.9983

# %% [markdown]
# ---
#
# 1. The error occurs because the output layer of your neural network uses a softmax activation, which is designed for multi-class classification problems and expects the target labels to be `one-hot encoded vectors`.
#
#           The `categorical_crossentropy loss` function also expects the target labels to be one-hot encoded.
#
# 2. Even though your labels are already numerical (0, 1, 2), `categorical_crossentropy` requires the labels to be in the format of `one-hot encoded vectors`, where each label is represented as a binary vector with a length equal to the number of classes.
#
#
# * **Model Output Shape:** The output layer of your model has 3 units with a softmax activation, which means the model will output a probability distribution over 3 classes for each input. This results in predictions with shape (batch_size, 3).
#
# * **Target Labels Shape:** Your target labels are currently integers (0, 1, 2) with shape (batch_size,). This is suitable for sparse categorical crossentropy but not for categorical crossentropy.
#
# * **Shape Mismatch:** When you use categorical_crossentropy loss, it expects the target labels to have the same shape as the model’s output, i.e., (batch_size, 3). This is why you need to convert the target labels to one-hot encoded vectors.
